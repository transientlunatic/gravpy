# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
import astropy.units as u
import astropy.constants as c

# %%
from interferometers import *
from sources import *
from timingarray import *
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-7-963de7452a64> in <module>
#       1 from interferometers import *
#       2 from sources import *
# ----> 3 from timingarray import *
#
# ~/repositories/grasshopper/notebooks/timingarray.py in <module>
#       2 import numpy as np
#       3 import matplotlib.pyplot as plt
# ----> 4 import data.atnf
#       5 import scipy.linalg as la
#       6 from astropy.io import ascii
#
# ~/repositories/grasshopper/notebooks/data/atnf.py in <module>
#       7 import pandas as pd
#       8 import datetime
# ----> 9 import astropy.table
#      10 import astropy.units as u
#      11 from astropy.time import Time
#
# ~/.virtualenvs/IGRlaptop21/thesis3/lib/python3.6/site-packages/astropy/table/__init__.py in <module>
#      56     from .jsviewer import JSViewer
#      57     from ..io.ascii import connect
# ---> 58     from ..io.fits import connect
#      59     from ..io.misc import connect
#      60     from ..io.votable import connect
#
# ~/.virtualenvs/IGRlaptop21/thesis3/lib/python3.6/site-packages/astropy/io/fits/__init__.py in <module>
#      68 from . import card
#      69 from . import column
# ---> 70 from . import convenience
#      71 from . import hdu
#      72 from .card import *
#
# ~/.virtualenvs/IGRlaptop21/thesis3/lib/python3.6/site-packages/astropy/io/fits/convenience.py in <module>
#      62 import numpy as np
#      63
# ---> 64 from .diff import FITSDiff, HDUDiff
#      65 from .file import FILE_MODES, _File
#      66 from .hdu.base import _BaseHDU, _ValidHDU
#
# ~/.virtualenvs/IGRlaptop21/thesis3/lib/python3.6/site-packages/astropy/io/fits/diff.py in <module>
#      29 from ...utils import indent
#      30 from .card import Card, BLANK_CARD
# ---> 31 from .header import Header
#      32 from ...utils.decorators import deprecated_renamed_argument
#      33 # HDUList is used in one of the doctests
#
# ~/.virtualenvs/IGRlaptop21/thesis3/lib/python3.6/site-packages/astropy/io/fits/header.py in <module>
#       8
#       9 from .card import Card, _pad, KEYWORD_LENGTH
# ---> 10 from .file import _File
#      11 from .util import encode_ascii, decode_ascii, fileobj_closed, fileobj_is_binary
#      12
#
# ~/.virtualenvs/IGRlaptop21/thesis3/lib/python3.6/site-packages/astropy/io/fits/file.py in <module>
#       2
#       3
# ----> 4 import bz2
#       5 import gzip
#       6 import http.client
#
# ~/.pyenv/versions/3.6.3/lib/python3.6/bz2.py in <module>
#      21     from dummy_threading import RLock
#      22
# ---> 23 from _bz2 import BZ2Compressor, BZ2Decompressor
#      24
#      25
#
# ModuleNotFoundError: No module named '_bz2'

# %%
# !pip install bz2
# Out:
# Collecting bz2
#   Could not find a version that satisfies the requirement bz2 (from versions: )
# No matching distribution found for bz2

# %%
# %matplotlib inline

# %%
frequencies = np.linspace(0, 1e5, 1000) * u.hertz
geo = GEO()
iligo = InitialLIGO()
tama = TAMA()
virgo = VIRGO()
aligo = AdvancedLIGO()
o1_aligo = AdvancedLIGO(configuration='O1')
elisa = EvolvedLISA()

# %%
ipta = IPTA()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-6-4e8ccb79a586> in <module>()
# ----> 1 ipta = IPTA()
#
# /home/daniel/ip-notebooks/gravwave-astronomy/timingarray.pyc in __init__(self)
#     185             cadence = pulsar['Cadence']*u.day
#     186             obstime = pulsar['Timespan']*u.year
# --> 187             self.pulsars.append(Pulsar(pulsar['Name'], cadence.to(u.second), obstime.to(u.second), pulsar['RMSRes'] ))
#     188
#
# /home/daniel/ip-notebooks/gravwave-astronomy/timingarray.pyc in __init__(self, psrj, cadence, obstime, rms)
#      41             The root mean square of the timing residuals for the pulsar.
#      42         """
# ---> 43         catalogue = data.atnf.get_atnf()
#      44         rowdata = catalogue.loc['PSRJ', psrj]
#      45         self.location = rowdata['POS']
#
# /home/daniel/ip-notebooks/gravwave-astronomy/data/atnf.pyc in get_atnf()
#      71         a['DM'].unit = u.centimeter**(-3) * u.parsec
#      72         #a['EDOT'].unit = u.erg / u.second
# ---> 73         a.add_index('Unnamed: 0')
#      74         a.rename_column('Unnamed: 0', '#')
#      75         a.add_index('PSRJ')
#
# /home/daniel/.virtualenvs/nbserver/local/lib/python2.7/site-packages/astropy/table/table.pyc in add_index(self, colnames, engine, unique)
#     477         if isinstance(colnames, six.string_types):
#     478             colnames = (colnames,)
# --> 479         columns = self.columns[tuple(colnames)].values()
#     480
#     481         # make sure all columns support indexing
#
# /home/daniel/.virtualenvs/nbserver/local/lib/python2.7/site-packages/astropy/table/table.pyc in __getitem__(self, item)
#     100             return self.values()[item]
#     101         elif isinstance(item, tuple):
# --> 102             return self.__class__([self[x] for x in item])
#     103         elif isinstance(item, slice):
#     104             return self.__class__([self[x] for x in list(self)[item]])
#
# /home/daniel/.virtualenvs/nbserver/local/lib/python2.7/site-packages/astropy/table/table.pyc in __getitem__(self, item)
#      96         """
#      97         if isinstance(item, six.string_types):
# ---> 98             return OrderedDict.__getitem__(self, item)
#      99         elif isinstance(item, (int, np.integer)):
#     100             return self.values()[item]
#
# KeyError: 'Unnamed: 0'

# %%
plt.style.use('/home/daniel/repositories/burst-style/burst.mplstyle')
f, ax = plt.subplots(1, figsize=(8,2.5))
geo.plot(axis = ax)
iligo.plot(ax)
tama.plot(ax)
virgo.plot(ax)
aligo.plot(ax)
o1_aligo.plot(ax)
elisa.plot(ax)
#ipta.plot(ax)
cbc = CBC(frequencies= np.logspace(-4, 5, 1000) * u.hertz, 
          m1=5*u.solMass, m2=5*u.solMass, r=1.2*1e9*u.parsec)
cbc.plot(ax)
#ax.plot(x, hp.data.data.real)
#ax.set_xlim([1e1,1e3]);
#ax.set_ylim([1e-23,1e-19]);
f.tight_layout()
#plt.savefig('cbc_spectrum.pgf')

# %%
gw150914 = BHBH(frequencies= np.logspace(-4, 5, 1000) * u.hertz, 
                m1=30*u.solMass, m2=32*u.solMass,
                S1=(0,0,0), S2=(0,0,0), R=100e6*u.parsec)

# %%
plt.style.use('/home/daniel/repositories/burst-style/burst.mplstyle')
f, ax = plt.subplots(1, figsize=(2.5,2.5))
gw150914.plot(ax)

# %%
print cbc.snr(o1_aligo), cbc.snr(elisa), cbc.snr(iligo)
# Out:
# 24.8134701645 109.12468906 6.37979047218

# %%
x, y, A,B,H = aligo.skymap(200, 100, psi=1)

# %%
plt.style.use('ggplot')
ax = plt.subplot(111, projection="hammer")
plt.pcolormesh(y-np.pi,x-np.pi/2., np.sqrt(H**2).T, cmap='viridis')
plt.colorbar(orientation='horizontal')
